# %%
import os
import cv2
import random
import pickle
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data_dir = 'F:/OneDrive - American International University-Bangladesh/Semester-10/COMPUTER VISION AND PATTERN RECOGNITION/fcr_data'

categories = []

for i in os.listdir(data_dir):
    category_path = os.path.join(data_dir, i)
    if os.path.isdir(category_path):
      num_files = len(os.listdir(category_path))
      if num_files > 6:
        categories.append(i)

print(categories)
print(f"Total class: {len(categories)}")
# Out:
# ['Ashiq', 'Dristi', 'Khushbu', 'MAYSHA', 'Mehrab', 'Nishat', 'Pranto', 'Rafsan', 'Rassel', 'Rizon', 'Rono', 'Sadi', 'Saif', 'Sakib', 'Sayem', 'Sintheia', 'Sumaiya', 'Tahsin']
# Total class: 18

# %%
plt.figure(figsize=(15,4))
i=0
for c in categories:  
    path = os.path.join(data_dir,c)
    try:
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img))
            plt.subplot(3,10,i+1)
            plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
            plt.xlabel(c)
            plt.xticks([])
            plt.yticks([])
            i += 1
            break
    except Exception as e:
        pass
plt.tight_layout()        
plt.show()

# %%
train_data = []
test_data = []
valid_data = []

split_ratio = 0.8

for c in categories:  
    path = os.path.join(data_dir, c)
    imgs = os.listdir(path) 
    random.shuffle(imgs)

    total_sample_num = len(imgs)
    train_sample_num = int(total_sample_num * split_ratio * 0.8)
    valid_sample_num = int(total_sample_num * split_ratio * 0.2)

    train_imgs = imgs[ : train_sample_num]
    valid_imgs = imgs[train_sample_num : train_sample_num + valid_sample_num]
    test_imgs =  imgs[train_sample_num + valid_sample_num : ]

    for img in tqdm(train_imgs, desc=f"Train data: {c}"):
        try:
            img_array = cv2.imread(os.path.join(path, img))   # read the image
            img_array= cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
            img_resized = cv2.resize(img_array, (256, 256))  # resize the image
            train_data.append([img_resized, categories.index(c)]) # [ [img, 0], [], [], [], ...., []]
        except Exception as e:
            pass
    
    for img in tqdm(valid_imgs, desc=f"Valid data: {c}"):
        try:
            img_array = cv2.imread(os.path.join(path, img))   # read the image
            img_array= cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
            img_resized = cv2.resize(img_array, (256, 256))  # resize the image
            valid_data.append([img_resized, categories.index(c)]) # [ [img, 0], [], [], [], ...., []]
        except Exception as e:
            pass
    
    for img in tqdm(test_imgs, desc=f"Test data: {c}"):
        try:
            img_array = cv2.imread(os.path.join(path, img))   # read the image
            img_array= cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
            img_resized = cv2.resize(img_array, (256, 256))  # resize the image
            test_data.append([img_resized, categories.index(c)]) # [ [img, 0], [], [], [], ...., []]
        except Exception as e:
            pass
# Out:
# Train data: Ashiq: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00,  8.28it/s]
# Valid data: Ashiq: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.26it/s]
# Test data: Ashiq: 100%|██████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  9.38it/s]
# Train data: Dristi: 100%|███████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 199.92it/s]
# Valid data: Dristi: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 499.38it/s]
# Test data: Dristi: 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 31.74it/s]
# Train data: Khushbu: 100%|███████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 36.47it/s]
# Valid data: Khushbu: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 95.15it/s]
# Test data: Khushbu: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 52.17it/s]
# Train data: MAYSHA: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 61.34it/s]
# Valid data: MAYSHA: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 153.84it/s]
# Test data: MAYSHA: 100%|█████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 43.47it/s]
# Train data: Mehrab: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 58.52it/s]
# Valid data: Mehrab: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 55.56it/s]
# Test data: Mehrab: 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 56.60it/s]
# Train data: Nishat: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 19.32it/s]
# Valid data: Nishat: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.12it/s]
# Test data: Nishat: 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 13.91it/s]
# Train data: Pranto: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 10.85it/s]
# Valid data: Pranto: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.67it/s]
# Test data: Pranto: 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.93it/s]
# Train data: Rafsan: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 41.51it/s]
# Valid data: Rafsan: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 36.36it/s]
# Test data: Rafsan: 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 40.80it/s]
# Train data: Rassel: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00,  6.45it/s]
# Valid data: Rassel: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.75it/s]
# Test data: Rassel: 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  6.71it/s]
# Train data: Rizon: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 35.29it/s]
# Valid data: Rizon: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 117.63it/s]
# Test data: Rizon: 100%|██████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 19.48it/s]
# Train data: Rono: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 100.82it/s]
# Valid data: Rono: 100%|██████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 95.27it/s]
# Test data: Rono: 100%|███████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 98.28it/s]
# Train data: Sadi: 100%|██████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 13.85it/s]
# Valid data: Sadi: 100%|██████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.60it/s]
# Test data: Sadi: 100%|███████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 53.55it/s]
# Train data: Saif: 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00,  9.09it/s]
# Valid data: Saif: 100%|██████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 27.38it/s]
# Test data: Saif: 100%|███████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  9.12it/s]
# Train data: Sakib: 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 20.10it/s]
# Valid data: Sakib: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 79.90it/s]
# Test data: Sakib: 100%|██████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 18.81it/s]
# Train data: Sayem: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00,  7.48it/s]
# Valid data: Sayem: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.13it/s]
# Test data: Sayem: 100%|██████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  6.02it/s]
# Train data: Sintheia: 100%|██████████████████████████████████████████████████████████████| 6/6 [00:00<00:00,  6.83it/s]
# Valid data: Sintheia: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.80it/s]
# Test data: Sintheia: 100%|███████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  7.01it/s]
# Train data: Sumaiya: 100%|███████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.58it/s]
# Valid data: Sumaiya: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.56it/s]
# Test data: Sumaiya: 100%|████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 12.22it/s]
# Train data: Tahsin: 100%|███████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 159.99it/s]
# Valid data: Tahsin: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 99.84it/s]
# Test data: Tahsin: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 142.86it/s]

# %%
# Shuffle the data
IMG_SIZE=256

random.shuffle(train_data)
random.shuffle(valid_data)
random.shuffle(test_data)

# Extract features (X) and labels (Y)
X_train, y_train = zip(*train_data)
X_valid, y_valid = zip(*valid_data)
X_test, y_test = zip(*test_data)

# Convert to numpy arrays and reshape
X_train = np.array(X_train).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y_train = np.array(y_train)
X_valid = np.array(X_valid).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y_valid = np.array(y_valid)
X_test = np.array(X_test).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y_test = np.array(y_test)

# Print the number of samples in each set
print("Number of training samples:", len(train_data))
print("Number of validation samples:", len(valid_data))
print("Number of test samples:", len(test_data))
# Out:
# Number of training samples: 105
# Number of validation samples: 18
# Number of test samples: 51

# %%
save_dir = 'F:/OneDrive - American International University-Bangladesh/Semester-10/COMPUTER VISION AND PATTERN RECOGNITION/CVPR/final/facial_recognition'

pickle_out = open(os.path.join(save_dir, "categories.pickle"),"wb")
pickle.dump(categories, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(save_dir, "X_train.pickle"),"wb")
pickle.dump(X_train, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(save_dir, "y_train.pickle"),"wb")
pickle.dump(y_train, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(save_dir, "X_valid.pickle"),"wb")
pickle.dump(X_valid, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(save_dir, "y_valid.pickle"),"wb")
pickle.dump(y_valid, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(save_dir, "X_test.pickle"),"wb")
pickle.dump(X_test, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(save_dir, "y_test.pickle"),"wb")
pickle.dump(y_test, pickle_out)
pickle_out.close()
